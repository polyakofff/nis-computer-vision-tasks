# %% [markdown]
# # Multiple object tracker
#
#
# Create multi-person tracker based on YOLOv5 detector and SORT tracker.
#
# * Download [MOT17](https://motchallenge.net/data/MOT17/) data for single video
# * Read the video, draw ground true bounding boxes along track id (in green color) and save new video in file *output.mp4* file.
# * Create person detector based on YOLO to get bounding boxes e.g. [YOLO-NAS](https://github.com/Deci-AI/super-gradients/blob/master/YOLONAS.md)
# * Create a simple tracker to get track_id for each bounding box detected. You may use the [norfair](https://github.com/tryolabs/norfair) or this legacy repo [SORT](https://arxiv.org/abs/1602.00763).
# * Append new bounding boxes along track id (in red color) to video  and save video to file *output.mp4*.

# %% [markdown]
# ###Download MOT17 data and labels

# %%
# !export MPLBACKEND=TKAgg

# %%
# Full data splitted by frames
# Really  we don't need it for this task but some images will be used for tests
# !wget https://motchallenge.net/data/MOT17Det.zip
# !unzip MOT17Det.zip

# Ground true bounding box
# !wget https://motchallenge.net/data/MOT17Labels.zip
# !unzip MOT17Labels.zip

# File with wideo
# Warning video resolution in this copy smaller than original video
# !wget https://motchallenge.net/sequenceVideos/MOT17-09-SDP-raw.webm

in_video = 'content/MOT17-09-SDP-raw.webm'
# Out:
# --2024-03-04 17:51:41--  https://motchallenge.net/data/MOT17Labels.zip
# Resolving motchallenge.net (motchallenge.net)... 131.159.19.34, 2a09:80c0:18::1034
# Connecting to motchallenge.net (motchallenge.net)|131.159.19.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10107022 (9.6M) [application/zip]
# Saving to: ‘MOT17Labels.zip’
#
# MOT17Labels.zip     100%[===================>]   9.64M  8.09MB/s    in 1.2s
#
# 2024-03-04 17:51:43 (8.09 MB/s) - ‘MOT17Labels.zip’ saved [10107022/10107022]
#
# Archive:  MOT17Labels.zip
#   inflating: test/MOT17-01-DPM/seqinfo.ini
#   inflating: test/MOT17-01-FRCNN/seqinfo.ini
#   inflating: test/MOT17-01-SDP/seqinfo.ini
#   inflating: test/MOT17-03-DPM/seqinfo.ini
#   inflating: test/MOT17-03-FRCNN/seqinfo.ini
#   inflating: test/MOT17-03-SDP/seqinfo.ini
#   inflating: test/MOT17-06-DPM/seqinfo.ini
#   inflating: test/MOT17-06-FRCNN/seqinfo.ini
#   inflating: test/MOT17-06-SDP/seqinfo.ini
#   inflating: test/MOT17-07-DPM/seqinfo.ini
#   inflating: test/MOT17-07-FRCNN/seqinfo.ini
#   inflating: test/MOT17-07-SDP/seqinfo.ini
#   inflating: test/MOT17-08-DPM/seqinfo.ini
#   inflating: test/MOT17-08-FRCNN/seqinfo.ini
#   inflating: test/MOT17-08-SDP/seqinfo.ini
#   inflating: test/MOT17-12-DPM/seqinfo.ini
#   inflating: test/MOT17-12-FRCNN/seqinfo.ini
#   inflating: test/MOT17-12-SDP/seqinfo.ini
#   inflating: test/MOT17-14-DPM/seqinfo.ini
#   inflating: test/MOT17-14-FRCNN/seqinfo.ini
#   inflating: test/MOT17-14-SDP/seqinfo.ini
#   inflating: train/MOT17-02-DPM/seqinfo.ini
#   inflating: train/MOT17-02-FRCNN/seqinfo.ini
#   inflating: train/MOT17-02-SDP/seqinfo.ini
#   inflating: train/MOT17-04-DPM/seqinfo.ini
#   inflating: train/MOT17-04-FRCNN/seqinfo.ini
#   inflating: train/MOT17-04-SDP/seqinfo.ini
#   inflating: train/MOT17-05-DPM/seqinfo.ini
#   inflating: train/MOT17-05-FRCNN/seqinfo.ini
#   inflating: train/MOT17-05-SDP/seqinfo.ini
#   inflating: train/MOT17-09-DPM/seqinfo.ini
#   inflating: train/MOT17-09-FRCNN/seqinfo.ini
#   inflating: train/MOT17-09-SDP/seqinfo.ini
#   inflating: train/MOT17-10-DPM/seqinfo.ini
#   inflating: train/MOT17-10-FRCNN/seqinfo.ini
#   inflating: train/MOT17-10-SDP/seqinfo.ini
#   inflating: train/MOT17-11-DPM/seqinfo.ini
#   inflating: train/MOT17-11-FRCNN/seqinfo.ini
#   inflating: train/MOT17-11-SDP/seqinfo.ini
#   inflating: train/MOT17-13-DPM/seqinfo.ini
#   inflating: train/MOT17-13-FRCNN/seqinfo.ini
#   inflating: train/MOT17-13-SDP/seqinfo.ini
#   inflating: test/MOT17-01-DPM/det/det.txt
#   inflating: test/MOT17-01-FRCNN/det/det.txt
#   inflating: test/MOT17-01-SDP/det/det.txt
#   inflating: test/MOT17-03-DPM/det/det.txt
#   inflating: test/MOT17-03-FRCNN/det/det.txt
#   inflating: test/MOT17-03-SDP/det/det.txt
#   inflating: test/MOT17-06-DPM/det/det.txt
#   inflating: test/MOT17-06-FRCNN/det/det.txt
#   inflating: test/MOT17-06-SDP/det/det.txt
#   inflating: test/MOT17-07-DPM/det/det.txt
#   inflating: test/MOT17-07-FRCNN/det/det.txt
#   inflating: test/MOT17-07-SDP/det/det.txt
#   inflating: test/MOT17-08-DPM/det/det.txt
#   inflating: test/MOT17-08-FRCNN/det/det.txt
#   inflating: test/MOT17-08-SDP/det/det.txt
#   inflating: test/MOT17-12-DPM/det/det.txt
#   inflating: test/MOT17-12-FRCNN/det/det.txt
#   inflating: test/MOT17-12-SDP/det/det.txt
#   inflating: test/MOT17-14-DPM/det/det.txt
#   inflating: test/MOT17-14-FRCNN/det/det.txt
#   inflating: test/MOT17-14-SDP/det/det.txt
#   inflating: train/MOT17-02-DPM/det/det.txt
#   inflating: train/MOT17-02-DPM/gt/gt.txt
#   inflating: train/MOT17-02-FRCNN/det/det.txt
#   inflating: train/MOT17-02-FRCNN/gt/gt.txt
#   inflating: train/MOT17-02-SDP/det/det.txt
#   inflating: train/MOT17-02-SDP/gt/gt.txt
#   inflating: train/MOT17-04-DPM/det/det.txt
#   inflating: train/MOT17-04-DPM/gt/gt.txt
#   inflating: train/MOT17-04-FRCNN/det/det.txt
#   inflating: train/MOT17-04-FRCNN/gt/gt.txt
#   inflating: train/MOT17-04-SDP/det/det.txt
#   inflating: train/MOT17-04-SDP/gt/gt.txt
#   inflating: train/MOT17-05-DPM/det/det.txt
#   inflating: train/MOT17-05-DPM/gt/gt.txt
#   inflating: train/MOT17-05-FRCNN/det/det.txt
#   inflating: train/MOT17-05-FRCNN/gt/gt.txt
#   inflating: train/MOT17-05-SDP/det/det.txt
#   inflating: train/MOT17-05-SDP/gt/gt.txt
#   inflating: train/MOT17-09-DPM/det/det.txt
#   inflating: train/MOT17-09-DPM/gt/gt.txt
#   inflating: train/MOT17-09-FRCNN/det/det.txt
#   inflating: train/MOT17-09-FRCNN/gt/gt.txt
#   inflating: train/MOT17-09-SDP/det/det.txt
#   inflating: train/MOT17-09-SDP/gt/gt.txt
#   inflating: train/MOT17-10-DPM/det/det.txt
#   inflating: train/MOT17-10-DPM/gt/gt.txt
#   inflating: train/MOT17-10-FRCNN/det/det.txt
#   inflating: train/MOT17-10-FRCNN/gt/gt.txt
#   inflating: train/MOT17-10-SDP/det/det.txt
#   inflating: train/MOT17-10-SDP/gt/gt.txt
#   inflating: train/MOT17-11-DPM/det/det.txt
#   inflating: train/MOT17-11-DPM/gt/gt.txt
#   inflating: train/MOT17-11-FRCNN/det/det.txt
#   inflating: train/MOT17-11-FRCNN/gt/gt.txt
#   inflating: train/MOT17-11-SDP/det/det.txt
#   inflating: train/MOT17-11-SDP/gt/gt.txt
#   inflating: train/MOT17-13-DPM/det/det.txt
#   inflating: train/MOT17-13-DPM/gt/gt.txt
#   inflating: train/MOT17-13-FRCNN/det/det.txt
#   inflating: train/MOT17-13-FRCNN/gt/gt.txt
#   inflating: train/MOT17-13-SDP/det/det.txt
#   inflating: train/MOT17-13-SDP/gt/gt.txt
# --2024-03-04 17:51:44--  https://motchallenge.net/sequenceVideos/MOT17-09-SDP-raw.webm
# Resolving motchallenge.net (motchallenge.net)... 131.159.19.34, 2a09:80c0:18::1034
# Connecting to motchallenge.net (motchallenge.net)|131.159.19.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5862269 (5.6M) [video/webm]
# Saving to: ‘MOT17-09-SDP-raw.webm’
#
# MOT17-09-SDP-raw.we 100%[===================>]   5.59M  5.81MB/s    in 1.0s
#
# 2024-03-04 17:51:45 (5.81 MB/s) - ‘MOT17-09-SDP-raw.webm’ saved [5862269/5862269]

# %% [markdown]
# ### Look at GT labels
#
# All frame numbers, target IDs and bounding boxes are 1-based. World coordinates x,y,z are ignored for the 2D challenge

# %%
import pandas as pd
#https://github.com/dendorferpatrick/MOTChallengeEvalKit/tree/master/MOT
gt = '/content/train/MOT17-09-SDP/gt/gt.txt'
labels = pd.read_csv(gt,
                     sep=',',
                     names=["frame", "id", "bb_left", "bb_top", "bb_width", "bb_height", "conf", "x", "y", "z"])

print(labels.iloc[[2]])
labels.head()
# Out:
#    frame  id  bb_left  bb_top  bb_width  bb_height  conf  x    y   z
# 2      3   1      264     449       102        263     1  1  1.0 NaN
#    frame  id  bb_left  bb_top  bb_width  bb_height  conf  x    y   z
# 0      1   1      260     450       102        262     1  1  1.0 NaN
# 1      2   1      262     449       102        263     1  1  1.0 NaN
# 2      3   1      264     449       102        263     1  1  1.0 NaN
# 3      4   1      266     448       102        264     1  1  1.0 NaN
# 4      5   1      268     448       102        264     1  1  1.0 NaN

# %% [markdown]
# ### Create person detector based on YOLO model

# %%
import torch

class PersonDetector:
  def __init__(self, conf=0.):
    # Place your code here
    self.conf = conf
    self.yolov5 = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

  def __call__(self,imgs):
    out = []
    # Return bboxes only

    # Place your code here
    tensors = self.yolov5(imgs).xyxy
    for xyxy_conf_class in tensors:
      out.append([row[0:5] for row in xyxy_conf_class.tolist() if int(row[5]) == 0 and row[4] >= self.conf])
    return out

# %% [markdown]
# ### Smoke test for your PersonDetector

# %%
detector = PersonDetector()
imgs = ['/content/train/MOT17-09/img1/000001.jpg','/content/train/MOT17-09/img1/000001.jpg']
bboxes_with_persons = detector(imgs)
print("Persons",bboxes_with_persons)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-4 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# Persons [[[1702.4849853515625, 388.0796203613281, 1849.8570556640625, 726.8543090820312], [255.37469482421875, 455.0041198730469, 353.5467834472656, 708.5975952148438], [1250.3433837890625, 539.3751220703125, 1309.13671875, 656.4786987304688], [1290.06884765625, 462.34735107421875, 1359.756591796875, 655.0717163085938], [0.0, 327.29327392578125, 90.8331527709961, 902.8020629882812], [114.92710876464844, 499.80279541015625, 202.2029571533203, 743.3346557617188], [1883.2677001953125, 382.0382385253906, 1919.7115478515625, 577.444091796875], [22.578678131103516, 439.1407470703125, 122.76732635498047, 829.257080078125], [860.9136352539062, 523.9013061523438, 901.0994262695312, 622.630126953125]], [[1702.4849853515625, 388.0796203613281, 1849.8570556640625, 726.8543090820312], [255.37469482421875, 455.0041198730469, 353.5467834472656, 708.5975952148438], [1250.3433837890625, 539.3751220703125, 1309.13671875, 656.4786987304688], [1290.06884765625, 462.34735107421875, 1359.756591796875, 655.0717163085938], [0.0, 327.29327392578125, 90.8331527709961, 902.8020629882812], [114.92710876464844, 499.80279541015625, 202.2029571533203, 743.3346557617188], [1883.2677001953125, 382.0382385253906, 1919.7115478515625, 577.444091796875], [22.578678131103516, 439.1407470703125, 122.76732635498047, 829.257080078125], [860.9136352539062, 523.9013061523438, 901.0994262695312, 622.630126953125]]]

# %% [markdown]
# ### Clone SORT
# https://github.com/abewley/sort.git
#
# or
#
# https://github.com/tryolabs/norfair

# %%
# SORT
# !git clone  https://github.com/abewley/sort.git
# !pip install -r sort/requirements.txt
# Out:
# Cloning into 'sort'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 208 (delta 2), reused 2 (delta 1), pack-reused 202
# Receiving objects: 100% (208/208), 1.21 MiB | 8.02 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# Collecting filterpy==1.4.5 (from -r sort/requirements.txt (line 1))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-image==0.17.2 (from -r sort/requirements.txt (line 2))
#   Downloading scikit-image-0.17.2.tar.gz (29.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lap==0.4.0 (from -r sort/requirements.txt (line 3))
#   Downloading lap-0.4.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from filterpy==1.4.5->-r sort/requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from filterpy==1.4.5->-r sort/requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from filterpy==1.4.5->-r sort/requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.17.2->-r sort/requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.17.2->-r sort/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.17.2->-r sort/requirements.txt (line 2)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.17.2->-r sort/requirements.txt (line 2)) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.17.2->-r sort/requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->filterpy==1.4.5->-r sort/requirements.txt (line 1)) (1.16.0)
# Building wheels for collected packages: filterpy, scikit-image, lap
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=63fc212925875b95ab132067bf1718f8d1a15363081ba205de01be5916fac19e
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
#   Building wheel for scikit-image (setup.py) ... done
#   Created wheel for scikit-image: filename=scikit_image-0.17.2-cp310-cp310-linux_x86_64.whl size=33220320 sha256=a2356fcd3dff974aec025aeda1eb5f5d9b646fbd2c99be369aa092452dd93aed
#   Stored in directory: /root/.cache/pip/wheels/30/fc/f4/10c6987c3a9cb937913fa19f8290e91e6f66df2440c2af6130
#   Building wheel for lap (setup.py) ... done
#   Created wheel for lap: filename=lap-0.4.0-cp310-cp310-linux_x86_64.whl size=1628951 sha256=12cef7f37e6ed67ffe6607460677ab9a44f0964c479bdf660bfc102e50f5199f
#   Stored in directory: /root/.cache/pip/wheels/00/42/2e/9dfe19270eea279d79e84767ff0d7b8082c3bf776cad00e83d
# Successfully built filterpy scikit-image lap
# Installing collected packages: lap, scikit-image, filterpy
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# Successfully installed filterpy-1.4.5 lap-0.4.0 scikit-image-0.17.2

# %%
# execfile('sort/sort.py')
# Out:
# usage: colab_kernel_launcher.py [-h] [--display] [--seq_path SEQ_PATH] [--phase PHASE]
#                                 [--max_age MAX_AGE] [--min_hits MIN_HITS]
#                                 [--iou_threshold IOU_THRESHOLD]
# colab_kernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-a5dc42f4-181a-4397-9e53-f4c4b4b71d18.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
import sys
sys.path.insert(0, '/content/sort')

# %%
gt = labels[labels['frame'] == 1][['bb_left', 'bb_top', 'bb_width', 'bb_height']]
gt
# Out:
#       bb_left  bb_top  bb_width  bb_height
# 0         260     450       102        262
# 3543     1686     387       171        345
# 3743     1886     327       156        404
# 3963     1253     533        63        129
# 4345     1292     459        70        202
# 4737     -348     235       477        695
# 5041     1035     174       136        532
# 5566      116     522        84        230
# 6091      234     395        21        440
# 6616     1682     470        65        122
# 7405       42     502        85        254
# 7930      863     522        46        108
# 8871      751     506        95        182

# %% [markdown]
# ### Place main code here
#
# You can use this code as a template:
#
# https://github.com/Gan4x4/CV-HSE2019/blob/master/video/exercise.ipynb

# %%
# from sort import Sort
import cv2
import multiprocessing as mp
import numpy as np

detector = PersonDetector() # YOLOv5 must be inside

# Open video input video

# Read video frame by frame

# Draw GT and predicted BB on ech frame along with track_id

# Save video with bounding boxes in `output.mp4` file

MAX_FRAMES = 1000
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = 30.0
width = 960
height = 540

def read_video(q):
  # Не работает, если создается в основном потоке
  stream = cv2.VideoCapture('/content/MOT17-09-SDP-raw.webm')
  fps = stream.get(cv2.CAP_PROP_FPS)
  width  = int(stream.get(cv2.CAP_PROP_FRAME_WIDTH))
  height = int(stream.get(cv2.CAP_PROP_FRAME_HEIGHT))
  total_frames = int(stream.get(cv2.CAP_PROP_FRAME_COUNT))
  total_frames = min(total_frames, MAX_FRAMES)
  print(fourcc, fps, width, height)
  i = 0
  while i < total_frames:
    ret, frame = stream.read()
    if ret:
      print(f'read video: frame {i}')
      q.put(frame)
      i += 1
    else:
      break

  q.put(None)
  print('reading done')
  stream.release()

def write_video(q):
  writer = cv2.VideoWriter('/content/output.mp4', fourcc=fourcc, fps=fps, frameSize=(width, height))
  i = 0
  while True:
    print(f'write video: frame {i}')
    frame = q.get()
    if frame is None:
      break
    writer.write(frame)
    i += 1

  print('writing done')
  writer.release()

def process_video(in_q, out_q, detector, tracker):
  i = 0
  while True:
    print(f'process video: frame {i}')
    frame = in_q.get()
    if frame is None:
      break

    gt = labels[labels['frame'] == i + 1][['bb_left', 'bb_top', 'bb_width', 'bb_height']]
    for _, row in gt.iterrows():
      # Я не очень разобрался, почему такие значения и почему они бывают отрицательными
      x1 = row[0] // 2
      y1 = (row[1] - row[3]) // 2
      x2 = (row[0] + row[2]) // 2
      y2 = row[1] // 2
      cv2.rectangle(frame, (x1,y1), (x2,y2), color=(0,0,255), thickness=1)

    detections = detector([frame])[0]
    trackings = tracker.update(np.array(detections))
    for tracking in trackings:
      x1 = int(tracking[0])
      y1 = int(tracking[1])
      x2 = int(tracking[2])
      y2 = int(tracking[3])
      id = int(tracking[4])
      cv2.rectangle(frame, (x1,y1), (x2,y2), color=(0,255,0), thickness=1)
      cv2.putText(frame, str(id), (x1,y1), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color=(0,255,0), thickness=1)
    out_q.put(frame)
    i += 1

  out_q.put(None)

in_q = mp.Queue()
read_video_ps = mp.Process(target=read_video, args=(in_q,))
read_video_ps.start()

out_q = mp.Queue()
write_video_ps = mp.Process(target=write_video, args=(out_q,))
write_video_ps.start()

tracker = Sort()
print(tracker)
# main process
process_video(in_q, out_q, detector, tracker)

read_video_ps.join()
write_video_ps.join()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-4 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# 1983148141 30.0 960 write video: frame 0540
#
# read video: frame 0
# read video: frame 1
# read video: frame 2
# read video: frame 3
#
# read video: frame 4read video: frame 5
# read video: frame 6
# read video: frame 7
# read video: frame 8
# <__main__.Sort object at 0x7970c26ba4a0>
# process video: frame 0
# read video: frame 9
# read video: frame 10
# read video: frame 11
# read video: frame 12
# read video: frame 13
# read video: frame 14
# read video: frame 15
# read video: frame 16
# read video: frame 17
# read video: frame 18
# read video: frame 19
# read video: frame 20
# read video: frame 21
# read video: frame 22
# read video: frame 23
# read video: frame 24
# read video: frame 25
# read video: frame 26
# read video: frame 27
# read video: frame 28
# read video: frame 29
# read video: frame 30
# read video: frame 31
# read video: frame 32
# read video: frame 33
# read video: frame 34
# read video: frame 35
# read video: frame 36
# read video: frame 37
# read video: frame 38
# read video: frame 39
# read video: frame 40
# read video: frame 41
# read video: frame 42
# read video: frame 43
# read video: frame 44
# read video: frame 45
# read video: frame 46
# read video: frame 47
# read video: frame 48
# read video: frame 49
# read video: frame 50
# read video: frame 51
# read video: frame 52
# read video: frame 53
# read video: frame 54
# read video: frame 55
# read video: frame 56
# read video: frame 57
# read video: frame 58
# read video: frame 59
# read video: frame 60write video: frame 1
#
# read video: frame 61
# read video: frame 62
# process video: frame 1
# read video: frame 63
# read video: frame 64
# read video: frame 65
# read video: frame 66
# read video: frame 67
# read video: frame 68
# read video: frame 69
# read video: frame 70
# read video: frame 71
# read video: frame 72
# read video: frame 73
# read video: frame 74
# read video: frame 75
# read video: frame 76
# read video: frame 77
# read video: frame 78
# read video: frame 79
# read video: frame 80
# read video: frame 81
# read video: frame 82
# read video: frame 83
# read video: frame 84
# read video: frame 85
# read video: frame 86
# read video: frame 87
# read video: frame 88
# read video: frame 89
# read video: frame 90
# read video: frame 91
# read video: frame 92
# read video: frame 93
# read video: frame 94
# read video: frame 95
# read video: frame 96
# read video: frame 97
# read video: frame 98
# read video: frame 99write video: frame 2
#
# read video: frame 100
# read video: frame 101
# read video: frame 102
# read video: frame 103
# process video: frame 2
# read video: frame 104
# read video: frame 105
# read video: frame 106
# read video: frame 107
# read video: frame 108
# read video: frame 109
# read video: frame 110
# read video: frame 111
# read video: frame 112
# read video: frame 113
# read video: frame 114
#
# read video: frame 115read video: frame 116
# read video: frame 117
# read video: frame 118
# read video: frame 119
# read video: frame 120
# read video: frame 121
# read video: frame 122
# read video: frame 123
# read video: frame 124
# read video: frame 125
# read video: frame 126
# read video: frame 127
# read video: frame 128
# read video: frame 129
# read video: frame 130
# read video: frame 131
# read video: frame 132
# read video: frame 133
# read video: frame 134
# read video: frame 135
# read video: frame 136
# read video: frame 137
# read video: frame 138
# write video: frame 3read video: frame 139
#
# read video: frame 140
# read video: frame 141
# read video: frame 142
# read video: frame 143
# read video: frame 144
# read video: frame 145
# process video: frame 3
# read video: frame 146
# read video: frame 147
# read video: frame 148
# read video: frame 149
# read video: frame 150
# read video: frame 151
# read video: frame 152
# read video: frame 153
# read video: frame 154
# read video: frame 155
# read video: frame 156
# read video: frame 157
# read video: frame 158
# read video: frame 159
# read video: frame 160
# read video: frame 161
# read video: frame 162
# read video: frame 163
# read video: frame 164
# read video: frame 165
# read video: frame 166
# read video: frame 167
# read video: frame 168
# read video: frame 169
# write video: frame 4
# read video: frame 170
# read video: frame 171
# read video: frame 172
# read video: frame 173
# read video: frame 174
# read video: frame 175process video: frame 4
#
# read video: frame 176
# read video: frame 177
# read video: frame 178
# read video: frame 179
# read video: frame 180
# read video: frame 181
# read video: frame 182
# read video: frame 183
# read video: frame 184
# read video: frame 185
# read video: frame 186
# read video: frame 187
# read video: frame 188
# read video: frame 189
# read video: frame 190
# read video: frame 191
# read video: frame 192
# read video: frame 193
# read video: frame 194
# read video: frame 195
# read video: frame 196
# read video: frame 197
# read video: frame 198
# read video: frame 199
# read video: frame 200
# write video: frame 5read video: frame 201
#
# read video: frame 202
# read video: frame 203
# read video: frame 204
# read video: frame 205
# read video: frame 206
# read video: frame 207
# read video: frame 208
# process video: frame 5
# read video: frame 209
# read video: frame 210
# read video: frame 211
# read video: frame 212
# read video: frame 213
# read video: frame 214
# read video: frame 215
# read video: frame 216
# read video: frame 217
# read video: frame 218
# read video: frame 219
# read video: frame 220
# read video: frame 221
# read video: frame 222
# read video: frame 223
# read video: frame 224
# read video: frame 225
# read video: frame 226
# read video: frame 227
# read video: frame 228
# read video: frame 229
# read video: frame 230
# read video: frame 231
# read video: frame 232
# read video: frame 233
# read video: frame 234
# read video: frame 235
# read video: frame 236
# read video: frame 237
# read video: frame 238
# read video: frame 239
# write video: frame 6
# read video: frame 240
# read video: frame 241
# read video: frame 242
# read video: frame 243
# read video: frame 244
# read video: frame 245
# read video: frame 246
# process video: frame 6
# read video: frame 247
# read video: frame 248
# read video: frame 249
# read video: frame 250
# read video: frame 251
# read video: frame 252
# read video: frame 253
# read video: frame 254
# read video: frame 255
# read video: frame 256
# read video: frame 257
# read video: frame 258
# read video: frame 259
# read video: frame 260
# read video: frame 261
# read video: frame 262
# read video: frame 263
# read video: frame 264
# read video: frame 265
# read video: frame 266
# read video: frame 267
# read video: frame 268
# read video: frame 269
# read video: frame 270
# read video: frame 271
# read video: frame 272
# read video: frame 273
# read video: frame 274
# read video: frame 275
# read video: frame 276
# read video: frame 277
# read video: frame 278write video: frame 7
#
# read video: frame 279
# read video: frame 280
# read video: frame 281
# read video: frame 282
# read video: frame 283
# read video: frame 284
# read video: frame 285
# read video: frame 286
# process video: frame 7
# read video: frame 287
# read video: frame 288
# read video: frame 289
# read video: frame 290
# read video: frame 291
# read video: frame 292
# read video: frame 293
# read video: frame 294
# read video: frame 295
# read video: frame 296
# read video: frame 297
# read video: frame 298
# read video: frame 299
# read video: frame 300
# read video: frame 301
# read video: frame 302
# read video: frame 303
# read video: frame 304
# read video: frame 305
# read video: frame 306
# read video: frame 307
# read video: frame 308
# read video: frame 309
# read video: frame 310
# read video: frame 311
# read video: frame 312
# read video: frame 313
# read video: frame 314
# read video: frame 315
# read video: frame 316
# read video: frame 317
# read video: frame 318
# read video: frame 319
# read video: frame 320
# write video: frame 8read video: frame 321
#
# read video: frame 322
# read video: frame 323
# read video: frame 324
# read video: frame 325
# read video: frame 326
# read video: frame 327
# read video: frame 328
# read video: frame 329process video: frame 8
#
# read video: frame 330
# read video: frame 331
# read video: frame 332
# read video: frame 333
# read video: frame 334
# read video: frame 335
# read video: frame 336
# read video: frame 337
# read video: frame 338
# read video: frame 339
# read video: frame 340
# read video: frame 341
# read video: frame 342
# read video: frame 343
# read video: frame 344
# read video: frame 345
# read video: frame 346
# read video: frame 347
# read video: frame 348
# read video: frame 349
# read video: frame 350
# read video: frame 351
# read video: frame 352
# read video: frame 353
# read video: frame 354
# read video: frame 355
# read video: frame 356
# read video: frame 357
# read video: frame 358
# read video: frame 359
# read video: frame 360
# read video: frame 361
# read video: frame 362
# read video: frame 363
# read video: frame 364
# read video: frame 365
# read video: frame 366
# read video: frame 367
# read video: frame 368
# read video: frame 369
# read video: frame 370write video: frame 9
#
# read video: frame 371
# read video: frame 372
# read video: frame 373
# read video: frame 374
# read video: frame 375
# read video: frame 376process video: frame 9
#
# read video: frame 377
# read video: frame 378
# read video: frame 379
# read video: frame 380
# read video: frame 381
# read video: frame 382
# read video: frame 383
# read video: frame 384
# read video: frame 385
# read video: frame 386
# read video: frame 387
# read video: frame 388
# read video: frame 389
# read video: frame 390
# read video: frame 391
# read video: frame 392
# read video: frame 393
# read video: frame 394
# read video: frame 395
# read video: frame 396
# read video: frame 397
# read video: frame 398
# read video: frame 399
# read video: frame 400
# read video: frame 401
# read video: frame 402
# read video: frame 403
# read video: frame 404
# read video: frame 405
# read video: frame 406
# write video: frame 10read video: frame 407
#
# read video: frame 408
# read video: frame 409
# read video: frame 410
# read video: frame 411
# read video: frame 412
# process video: frame 10
# read video: frame 413
# read video: frame 414
# read video: frame 415
# read video: frame 416
# read video: frame 417
# read video: frame 418
# read video: frame 419
# read video: frame 420
# read video: frame 421
# read video: frame 422
# read video: frame 423
# read video: frame 424
# read video: frame 425
# read video: frame 426
# read video: frame 427
# read video: frame 428
# read video: frame 429
# read video: frame 430
# read video: frame 431
# read video: frame 432
# read video: frame 433
# read video: frame 434
# read video: frame 435
# read video: frame 436
# read video: frame 437
# read video: frame 438
# read video: frame 439
# read video: frame 440
# read video: frame 441
# read video: frame 442
# write video: frame 11read video: frame 443
#
# read video: frame 444
# read video: frame 445
# read video: frame 446
# read video: frame 447
# read video: frame 448process video: frame 11
#
# read video: frame 449
# read video: frame 450
# read video: frame 451
# read video: frame 452
# read video: frame 453
# read video: frame 454
# read video: frame 455
# read video: frame 456
# read video: frame 457
# read video: frame 458
# read video: frame 459
# read video: frame 460
# read video: frame 461
# read video: frame 462
# read video: frame 463
# read video: frame 464
# read video: frame 465
# read video: frame 466
# read video: frame 467
# read video: frame 468
# read video: frame 469
# read video: frame 470
# read video: frame 471
# write video: frame 12read video: frame 472
#
# read video: frame 473
# read video: frame 474
# read video: frame 475
# read video: frame 476
# process video: frame 12
# read video: frame 477
# read video: frame 478
# read video: frame 479
# read video: frame 480
# read video: frame 481
# read video: frame 482
# read video: frame 483
# read video: frame 484
# read video: frame 485
# read video: frame 486
# read video: frame 487
# read video: frame 488
# read video: frame 489
# read video: frame 490
# read video: frame 491
# read video: frame 492
# read video: frame 493
# read video: frame 494
# read video: frame 495
# read video: frame 496
# read video: frame 497
# read video: frame 498
# read video: frame 499
# read video: frame 500
# read video: frame 501
# read video: frame 502
# read video: frame 503
# read video: frame 504
# read video: frame 505
# read video: frame 506
# read video: frame 507
# read video: frame 508
# read video: frame 509
# read video: frame 510
# read video: frame 511
# read video: frame 512write video: frame 13
#
# read video: frame 513
# read video: frame 514
# read video: frame 515
# read video: frame 516
# read video: frame 517
# read video: frame 518
# process video: frame 13
# read video: frame 519
# read video: frame 520
# read video: frame 521
# read video: frame 522
# read video: frame 523
# read video: frame 524
# reading done
# write video: frame 14
# process video: frame 14
# write video: frame 15
# process video: frame 15
# write video: frame 16
# process video: frame 16
# write video: frame 17
# process video: frame 17
# write video: frame 18
# process video: frame 18
# write video: frame 19
# process video: frame 19
# write video: frame 20
# process video: frame 20
# write video: frame 21
# process video: frame 21
# write video: frame 22
# process video: frame 22
# write video: frame 23
# process video: frame 23
# write video: frame 24
# process video: frame 24
# write video: frame 25
# process video: frame 25
# write video: frame 26
# process video: frame 26
# write video: frame 27
# process video: frame 27
# write video: frame 28
# process video: frame 28
# write video: frame 29
# process video: frame 29
# write video: frame 30
# process video: frame 30
# write video: frame 31
# process video: frame 31
# write video: frame 32
# process video: frame 32
# write video: frame 33
# process video: frame 33
# write video: frame 34
# process video: frame 34
# write video: frame 35
# process video: frame 35
# write video: frame 36
# process video: frame 36
# write video: frame 37
# process video: frame 37
# write video: frame 38
# process video: frame 38
# write video: frame 39
# process video: frame 39
# write video: frame 40
# process video: frame 40
# write video: frame 41
# process video: frame 41
# write video: frame 42
# process video: frame 42
# write video: frame 43
# process video: frame 43
# write video: frame 44
# process video: frame 44
# write video: frame 45
# process video: frame 45
# write video: frame 46
# process video: frame 46
# write video: frame 47
# process video: frame 47
# write video: frame 48
# process video: frame 48
# write video: frame 49
# process video: frame 49
# write video: frame 50
# process video: frame 50
# write video: frame 51
# process video: frame 51
# write video: frame 52
# process video: frame 52
# write video: frame 53
# process video: frame 53
# write video: frame 54
# process video: frame 54
# write video: frame 55
# process video: frame 55
# write video: frame 56
# process video: frame 56
# write video: frame 57
# process video: frame 57
# write video: frame 58
# process video: frame 58
# write video: frame 59
# process video: frame 59
# write video: frame 60
# process video: frame 60
# write video: frame 61
# process video: frame 61
# write video: frame 62
# process video: frame 62
# write video: frame 63
# process video: frame 63
# write video: frame 64
# process video: frame 64
# write video: frame 65
# process video: frame 65
# write video: frame 66
# process video: frame 66
# write video: frame 67
# process video: frame 67
# write video: frame 68
# process video: frame 68
# write video: frame 69
# process video: frame 69
# write video: frame 70
# process video: frame 70
# write video: frame 71
# process video: frame 71
# write video: frame 72
# process video: frame 72
# write video: frame 73
# process video: frame 73
# write video: frame 74
# process video: frame 74
# write video: frame 75
# process video: frame 75
# write video: frame 76
# process video: frame 76
# write video: frame 77
# process video: frame 77
# write video: frame 78
# process video: frame 78
# write video: frame 79
# process video: frame 79
# write video: frame 80
# process video: frame 80
# write video: frame 81
# process video: frame 81
# write video: frame 82
# process video: frame 82
# write video: frame 83
# process video: frame 83
# write video: frame 84
# process video: frame 84
# write video: frame 85
# process video: frame 85
# write video: frame 86
# process video: frame 86
# write video: frame 87
# process video: frame 87
# write video: frame 88
# process video: frame 88
# write video: frame 89
# process video: frame 89
# write video: frame 90
# process video: frame 90
# write video: frame 91
# process video: frame 91
# write video: frame 92
# process video: frame 92
# write video: frame 93
# process video: frame 93
# write video: frame 94
# process video: frame 94
# write video: frame 95
# process video: frame 95
# write video: frame 96
# process video: frame 96
# write video: frame 97
# process video: frame 97
# write video: frame 98
# process video: frame 98
# write video: frame 99
# process video: frame 99
# write video: frame 100
# process video: frame 100
# write video: frame 101
# process video: frame 101
# write video: frame 102
# process video: frame 102
# write video: frame 103
# process video: frame 103
# write video: frame 104
# process video: frame 104
# write video: frame 105
# process video: frame 105
# write video: frame 106
# process video: frame 106
# write video: frame 107
# process video: frame 107
# write video: frame 108
# process video: frame 108
# write video: frame 109
# process video: frame 109
# write video: frame 110
# process video: frame 110
# write video: frame 111
# process video: frame 111
# write video: frame 112
# process video: frame 112
# write video: frame 113
# process video: frame 113
# write video: frame 114
# process video: frame 114
# write video: frame 115
# process video: frame 115
# write video: frame 116
# process video: frame 116
# write video: frame 117
# process video: frame 117
# write video: frame 118
# process video: frame 118
# write video: frame 119
# process video: frame 119
# write video: frame 120
# process video: frame 120
# write video: frame 121
# process video: frame 121
# write video: frame 122
# process video: frame 122
# write video: frame 123
# process video: frame 123
# write video: frame 124
# process video: frame 124
# write video: frame 125
# process video: frame 125
# write video: frame 126
# process video: frame 126
# write video: frame 127
# process video: frame 127
# write video: frame 128
# process video: frame 128
# write video: frame 129
# process video: frame 129
# write video: frame 130
# process video: frame 130
# write video: frame 131
# process video: frame 131
# write video: frame 132
# process video: frame 132
# write video: frame 133
# process video: frame 133
# write video: frame 134
# process video: frame 134
# write video: frame 135
# process video: frame 135
# write video: frame 136
# process video: frame 136
# write video: frame 137
# process video: frame 137
# write video: frame 138
# process video: frame 138
# write video: frame 139
# process video: frame 139
# write video: frame 140
# process video: frame 140
# write video: frame 141
# process video: frame 141
# write video: frame 142
# process video: frame 142
# write video: frame 143
# process video: frame 143
# write video: frame 144
# process video: frame 144
# write video: frame 145
# process video: frame 145
# write video: frame 146
# process video: frame 146
# write video: frame 147
# process video: frame 147
# write video: frame 148
# process video: frame 148
# write video: frame 149
# process video: frame 149
# write video: frame 150
# process video: frame 150
# write video: frame 151
# process video: frame 151
# write video: frame 152
# process video: frame 152
# write video: frame 153
# process video: frame 153
# write video: frame 154
# process video: frame 154
# write video: frame 155
# process video: frame 155
# write video: frame 156
# process video: frame 156
# write video: frame 157
# process video: frame 157
# write video: frame 158
# process video: frame 158
# write video: frame 159
# process video: frame 159
# write video: frame 160
# process video: frame 160
# write video: frame 161
# process video: frame 161
# write video: frame 162
# process video: frame 162
# write video: frame 163
# process video: frame 163
# write video: frame 164
# process video: frame 164
# write video: frame 165
# process video: frame 165
# write video: frame 166
# process video: frame 166
# write video: frame 167
# process video: frame 167
# write video: frame 168
# process video: frame 168
# write video: frame 169
# process video: frame 169
# write video: frame 170
# process video: frame 170
# write video: frame 171
# process video: frame 171
# write video: frame 172
# process video: frame 172
# write video: frame 173
# process video: frame 173
# write video: frame 174
# process video: frame 174
# write video: frame 175
# process video: frame 175
# write video: frame 176
# process video: frame 176
# write video: frame 177
# process video: frame 177
# write video: frame 178
# process video: frame 178
# write video: frame 179
# process video: frame 179
# write video: frame 180
# process video: frame 180
# write video: frame 181
# process video: frame 181
# write video: frame 182
# process video: frame 182
# write video: frame 183
# process video: frame 183
# write video: frame 184
# process video: frame 184
# write video: frame 185
# process video: frame 185
# write video: frame 186
# process video: frame 186
# write video: frame 187
# process video: frame 187
# write video: frame 188
# process video: frame 188
# write video: frame 189
# process video: frame 189
# write video: frame 190
# process video: frame 190
# write video: frame 191
# process video: frame 191
# write video: frame 192
# process video: frame 192
# write video: frame 193
# process video: frame 193
# write video: frame 194
# process video: frame 194
# write video: frame 195
# process video: frame 195
# write video: frame 196
# process video: frame 196
# write video: frame 197
# process video: frame 197
# write video: frame 198
# process video: frame 198
# write video: frame 199
# process video: frame 199
# write video: frame 200
# process video: frame 200
# write video: frame 201
# process video: frame 201
# write video: frame 202
# process video: frame 202
# write video: frame 203
# process video: frame 203
# write video: frame 204
# process video: frame 204
# write video: frame 205
# process video: frame 205
# write video: frame 206
# process video: frame 206
# write video: frame 207
# process video: frame 207
# write video: frame 208
# process video: frame 208
# write video: frame 209
# process video: frame 209
# write video: frame 210
# process video: frame 210
# write video: frame 211
# process video: frame 211
# write video: frame 212
# process video: frame 212
# write video: frame 213
# process video: frame 213
# write video: frame 214
# process video: frame 214
# write video: frame 215
# process video: frame 215
# write video: frame 216
# process video: frame 216
# write video: frame 217
# process video: frame 217
# write video: frame 218
# process video: frame 218
# write video: frame 219
# process video: frame 219
# write video: frame 220
# process video: frame 220
# write video: frame 221
# process video: frame 221
# write video: frame 222
# process video: frame 222
# write video: frame 223
# process video: frame 223
# write video: frame 224
# process video: frame 224
# write video: frame 225
# process video: frame 225
# write video: frame 226
# process video: frame 226
# write video: frame 227
# process video: frame 227
# write video: frame 228
# process video: frame 228
# write video: frame 229
# process video: frame 229
# write video: frame 230
# process video: frame 230
# write video: frame 231
# process video: frame 231
# write video: frame 232
# process video: frame 232
# write video: frame 233
# process video: frame 233
# write video: frame 234
# process video: frame 234
# write video: frame 235
# process video: frame 235
# write video: frame 236
# process video: frame 236
# write video: frame 237
# process video: frame 237
# write video: frame 238
# process video: frame 238
# write video: frame 239
# process video: frame 239
# write video: frame 240
# process video: frame 240
# write video: frame 241
# process video: frame 241
# write video: frame 242
# process video: frame 242
# write video: frame 243
# process video: frame 243
# write video: frame 244
# process video: frame 244
# write video: frame 245
# process video: frame 245
# write video: frame 246
# process video: frame 246
# write video: frame 247
# process video: frame 247
# write video: frame 248
# process video: frame 248
# write video: frame 249
# process video: frame 249
# write video: frame 250
# process video: frame 250
# write video: frame 251
# process video: frame 251
# write video: frame 252
# process video: frame 252
# write video: frame 253
# process video: frame 253
# write video: frame 254
# process video: frame 254
# write video: frame 255
# process video: frame 255
# write video: frame 256
# process video: frame 256
# write video: frame 257
# process video: frame 257
# write video: frame 258
# process video: frame 258
# write video: frame 259
# process video: frame 259
# write video: frame 260
# process video: frame 260
# write video: frame 261
# process video: frame 261
# write video: frame 262
# process video: frame 262
# write video: frame 263
# process video: frame 263
# write video: frame 264
# process video: frame 264
# write video: frame 265
# process video: frame 265
# write video: frame 266
# process video: frame 266
# write video: frame 267
# process video: frame 267
# write video: frame 268
# process video: frame 268
# write video: frame 269
# process video: frame 269
# write video: frame 270
# process video: frame 270
# write video: frame 271
# process video: frame 271
# write video: frame 272
# process video: frame 272
# write video: frame 273
# process video: frame 273
# write video: frame 274
# process video: frame 274
# write video: frame 275
# process video: frame 275
# write video: frame 276
# process video: frame 276
# write video: frame 277
# process video: frame 277
# write video: frame 278
# process video: frame 278
# write video: frame 279
# process video: frame 279
# write video: frame 280
# process video: frame 280
# write video: frame 281
# process video: frame 281
# write video: frame 282
# process video: frame 282
# write video: frame 283
# process video: frame 283
# write video: frame 284
# process video: frame 284
# write video: frame 285
# process video: frame 285
# write video: frame 286
# process video: frame 286
# write video: frame 287
# process video: frame 287
# write video: frame 288
# process video: frame 288
# write video: frame 289
# process video: frame 289
# write video: frame 290
# process video: frame 290
# write video: frame 291
# process video: frame 291
# write video: frame 292
# process video: frame 292
# write video: frame 293
# process video: frame 293
# write video: frame 294
# process video: frame 294
# write video: frame 295
# process video: frame 295
# write video: frame 296
# process video: frame 296
# write video: frame 297
# process video: frame 297
# write video: frame 298
# process video: frame 298
# write video: frame 299
# process video: frame 299
# write video: frame 300
# process video: frame 300
# write video: frame 301
# process video: frame 301
# write video: frame 302
# process video: frame 302
# write video: frame 303
# process video: frame 303
# write video: frame 304
# process video: frame 304
# write video: frame 305
# process video: frame 305
# write video: frame 306
# process video: frame 306
# write video: frame 307
# process video: frame 307
# write video: frame 308
# process video: frame 308
# write video: frame 309
# process video: frame 309
# write video: frame 310
# process video: frame 310
# write video: frame 311
# process video: frame 311
# write video: frame 312
# process video: frame 312
# write video: frame 313
# process video: frame 313
# write video: frame 314
# process video: frame 314
# write video: frame 315
# process video: frame 315
# write video: frame 316
# process video: frame 316
# write video: frame 317
# process video: frame 317
# write video: frame 318
# process video: frame 318
# write video: frame 319
# process video: frame 319
# write video: frame 320
# process video: frame 320
# write video: frame 321
# process video: frame 321
# write video: frame 322
# process video: frame 322
# write video: frame 323
# process video: frame 323
# write video: frame 324
# process video: frame 324
# write video: frame 325
# process video: frame 325
# write video: frame 326
# process video: frame 326
# write video: frame 327
# process video: frame 327
# write video: frame 328
# process video: frame 328
# write video: frame 329
# process video: frame 329
# write video: frame 330
# process video: frame 330
# write video: frame 331
# process video: frame 331
# write video: frame 332
# process video: frame 332
# write video: frame 333
# process video: frame 333
# write video: frame 334
# process video: frame 334
# write video: frame 335
# process video: frame 335
# write video: frame 336
# process video: frame 336
# write video: frame 337
# process video: frame 337
# write video: frame 338
# process video: frame 338
# write video: frame 339
# process video: frame 339
# write video: frame 340
# process video: frame 340
# write video: frame 341
# process video: frame 341
# write video: frame 342
# process video: frame 342
# write video: frame 343
# process video: frame 343
# write video: frame 344
# process video: frame 344
# write video: frame 345
# process video: frame 345
# write video: frame 346
# process video: frame 346
# write video: frame 347
# process video: frame 347
# write video: frame 348
# process video: frame 348
# write video: frame 349
# process video: frame 349
# write video: frame 350
# process video: frame 350
# write video: frame 351
# process video: frame 351
# write video: frame 352
# process video: frame 352
# write video: frame 353
# process video: frame 353
# write video: frame 354
# process video: frame 354
# write video: frame 355
# process video: frame 355
# write video: frame 356
# process video: frame 356
# write video: frame 357
# process video: frame 357
# write video: frame 358
# process video: frame 358
# write video: frame 359
# process video: frame 359
# write video: frame 360
# process video: frame 360
# write video: frame 361
# process video: frame 361
# write video: frame 362
# process video: frame 362
# write video: frame 363
# process video: frame 363
# write video: frame 364
# process video: frame 364
# write video: frame 365
# process video: frame 365
# write video: frame 366
# process video: frame 366
# write video: frame 367
# process video: frame 367
# write video: frame 368
# process video: frame 368
# write video: frame 369
# process video: frame 369
# write video: frame 370
# process video: frame 370
# write video: frame 371
# process video: frame 371
# write video: frame 372
# process video: frame 372
# write video: frame 373
# process video: frame 373
# write video: frame 374
# process video: frame 374
# write video: frame 375
# process video: frame 375
# write video: frame 376
# process video: frame 376
# write video: frame 377
# process video: frame 377
# write video: frame 378
# process video: frame 378
# write video: frame 379
# process video: frame 379
# write video: frame 380
# process video: frame 380
# write video: frame 381
# process video: frame 381
# write video: frame 382
# process video: frame 382
# write video: frame 383
# process video: frame 383
# write video: frame 384
# process video: frame 384
# write video: frame 385
# process video: frame 385
# write video: frame 386
# process video: frame 386
# write video: frame 387
# process video: frame 387
# write video: frame 388
# process video: frame 388
# write video: frame 389
# process video: frame 389
# write video: frame 390
# process video: frame 390
# write video: frame 391
# process video: frame 391
# write video: frame 392
# process video: frame 392
# write video: frame 393
# process video: frame 393
# write video: frame 394
# process video: frame 394
# write video: frame 395
# process video: frame 395
# write video: frame 396
# process video: frame 396
# write video: frame 397
# process video: frame 397
# write video: frame 398
# process video: frame 398
# write video: frame 399
# process video: frame 399
# write video: frame 400
# process video: frame 400
# write video: frame 401
# process video: frame 401
# write video: frame 402
# process video: frame 402
# write video: frame 403
# process video: frame 403
# write video: frame 404
# process video: frame 404
# write video: frame 405
# process video: frame 405
# write video: frame 406
# process video: frame 406
# write video: frame 407
# process video: frame 407
# write video: frame 408
# process video: frame 408
# write video: frame 409
# process video: frame 409
# write video: frame 410
# process video: frame 410
# write video: frame 411
# process video: frame 411
# write video: frame 412
# process video: frame 412
# write video: frame 413
# process video: frame 413
# write video: frame 414
# process video: frame 414
# write video: frame 415
# process video: frame 415
# write video: frame 416
# process video: frame 416
# write video: frame 417
# process video: frame 417
# write video: frame 418
# process video: frame 418
# write video: frame 419
# process video: frame 419
# write video: frame 420
# process video: frame 420
# write video: frame 421
# process video: frame 421
# write video: frame 422
# process video: frame 422
# write video: frame 423
# process video: frame 423
# write video: frame 424
# process video: frame 424
# write video: frame 425
# process video: frame 425
# write video: frame 426
# process video: frame 426
# write video: frame 427
# process video: frame 427
# write video: frame 428
# process video: frame 428
# write video: frame 429
# process video: frame 429
# write video: frame 430
# process video: frame 430
# write video: frame 431
# process video: frame 431
# write video: frame 432
# process video: frame 432
# write video: frame 433
# process video: frame 433
# write video: frame 434
# process video: frame 434
# write video: frame 435
# process video: frame 435
# write video: frame 436
# process video: frame 436
# write video: frame 437
# process video: frame 437
# write video: frame 438
# process video: frame 438
# write video: frame 439
# process video: frame 439
# write video: frame 440
# process video: frame 440
# write video: frame 441
# process video: frame 441
# write video: frame 442
# process video: frame 442
# write video: frame 443
# process video: frame 443
# write video: frame 444
# process video: frame 444
# write video: frame 445
# process video: frame 445
# write video: frame 446
# process video: frame 446
# write video: frame 447
# process video: frame 447
# write video: frame 448
# process video: frame 448
# write video: frame 449
# process video: frame 449
# write video: frame 450
# process video: frame 450
# write video: frame 451
# process video: frame 451
# write video: frame 452
# process video: frame 452
# write video: frame 453
# process video: frame 453
# write video: frame 454
# process video: frame 454
# write video: frame 455
# process video: frame 455
# write video: frame 456
# process video: frame 456
# write video: frame 457
# process video: frame 457
# write video: frame 458
# process video: frame 458
# write video: frame 459
# process video: frame 459
# write video: frame 460
# process video: frame 460
# write video: frame 461
# process video: frame 461
# write video: frame 462
# process video: frame 462
# write video: frame 463
# process video: frame 463
# write video: frame 464
# process video: frame 464
# write video: frame 465
# process video: frame 465
# write video: frame 466
# process video: frame 466
# write video: frame 467
# process video: frame 467
# write video: frame 468
# process video: frame 468
# write video: frame 469
# process video: frame 469
# write video: frame 470
# process video: frame 470
# write video: frame 471
# process video: frame 471
# write video: frame 472
# process video: frame 472
# write video: frame 473
# process video: frame 473
# write video: frame 474
# process video: frame 474
# write video: frame 475
# process video: frame 475
# write video: frame 476
# process video: frame 476
# write video: frame 477
# process video: frame 477
# write video: frame 478
# process video: frame 478
# write video: frame 479
# process video: frame 479
# write video: frame 480
# process video: frame 480
# write video: frame 481
# process video: frame 481
# write video: frame 482
# process video: frame 482
# write video: frame 483
# process video: frame 483
# write video: frame 484
# process video: frame 484
# write video: frame 485
# process video: frame 485
# write video: frame 486
# process video: frame 486
# write video: frame 487
# process video: frame 487
# write video: frame 488
# process video: frame 488
# write video: frame 489
# process video: frame 489
# write video: frame 490
# process video: frame 490
# write video: frame 491
# process video: frame 491
# write video: frame 492
# process video: frame 492
# write video: frame 493
# process video: frame 493
# write video: frame 494
# process video: frame 494
# write video: frame 495
# process video: frame 495
# write video: frame 496
# process video: frame 496
# write video: frame 497
# process video: frame 497
# write video: frame 498
# process video: frame 498
# write video: frame 499
# process video: frame 499
# write video: frame 500
# process video: frame 500
# write video: frame 501
# process video: frame 501
# write video: frame 502
# process video: frame 502
# write video: frame 503
# process video: frame 503
# write video: frame 504
# process video: frame 504
# write video: frame 505
# process video: frame 505
# write video: frame 506
# process video: frame 506
# write video: frame 507
# process video: frame 507
# write video: frame 508
# process video: frame 508
# write video: frame 509
# process video: frame 509
# write video: frame 510
# process video: frame 510
# write video: frame 511
# process video: frame 511
# write video: frame 512
# process video: frame 512
# write video: frame 513
# process video: frame 513
# write video: frame 514
# process video: frame 514
# write video: frame 515
# process video: frame 515
# write video: frame 516
# process video: frame 516
# write video: frame 517
# process video: frame 517
# write video: frame 518
# process video: frame 518
# write video: frame 519
# process video: frame 519
# write video: frame 520
# process video: frame 520
# write video: frame 521
# process video: frame 521
# write video: frame 522
# process video: frame 522
# write video: frame 523
# process video: frame 523
# write video: frame 524
# process video: frame 524
# write video: frame 525
# writing done
# process video: frame 525

# %% [markdown]
# ## Test speed of your code , and place brief conclusion here:
#
# Видно, что задетектировать объекты получилось достаточно точно, хотя track_id немного хромают. Ну и еще это очень долго работает. Наверное можно в process_video перебирать по несколько кадров. Попробую

# %% [markdown]
# # Ideas for Extra work
#
# * Measure overall speed of your tracker in FPS (Frame per second)
# * Calculate tracking metrics (MOTA, MOTP)
# * Try different tracker
